# %%
import requests
import os

# %%
urls = [
"https://arxiv.org/pdf/astro-ph/0505226",
"https://arxiv.org/pdf/0706.0516",
"https://arxiv.org/pdf/1009.4505",
"https://arxiv.org/pdf/1606.07790",
"https://arxiv.org/pdf/1707.04256",
"https://arxiv.org/pdf/1809.07431",
"https://arxiv.org/pdf/1904.10471",
"https://arxiv.org/pdf/1912.12278",
"https://arxiv.org/pdf/2008.08954",
"https://arxiv.org/pdf/2009.04256",
"https://arxiv.org/pdf/2105.05208",
"https://arxiv.org/pdf/2107.03478",
"https://arxiv.org/pdf/2110.05499",
"https://arxiv.org/pdf/2206.05295",
"https://arxiv.org/pdf/2206.08763",
"https://arxiv.org/pdf/2207.11992",
"https://arxiv.org/pdf/2211.12574",
"https://arxiv.org/pdf/2302.02646",
"https://arxiv.org/pdf/2311.05439",
"https://arxiv.org/pdf/2401.16002",
"https://arxiv.org/pdf/2402.05392",
"https://arxiv.org/pdf/2403.08717",
"https://arxiv.org/pdf/2405.03769",
"https://arxiv.org/pdf/2405.05303",
"https://arxiv.org/pdf/2410.07792",
]

# %%
len(urls)
# Out:
# 25

# %%
folder_path = '/home/holman/Downloads/MS_arts/'

# %%
if not os.path.exists(folder_path):
    os.makedirs(folder_path)

# %%
def download_pdfs(urls, folder):
    for url in urls:
        response = requests.get(url)
        filename = url.split('/')[-1] + '.pdf'
        file_path = os.path.join(folder, filename)
        with open(file_path, 'wb') as f:
            f.write(response.content)
        print(f'Descargado: {filename}')

# %%
download_pdfs(urls, folder_path)
# Out:
# Descargado: 0505226.pdf
# Descargado: 0706.0516.pdf
# Descargado: 1009.4505.pdf
# Descargado: 1606.07790.pdf
# Descargado: 1707.04256.pdf
# Descargado: 1809.07431.pdf
# Descargado: 1904.10471.pdf
# Descargado: 1912.12278.pdf
# Descargado: 2008.08954.pdf
# Descargado: 2009.04256.pdf
# Descargado: 2105.05208.pdf
# Descargado: 2107.03478.pdf
# Descargado: 2110.05499.pdf
# Descargado: 2206.05295.pdf
# Descargado: 2206.08763.pdf
# Descargado: 2207.11992.pdf
# Descargado: 2211.12574.pdf
# Descargado: 2302.02646.pdf
# Descargado: 2311.05439.pdf
# Descargado: 2401.16002.pdf
# Descargado: 2402.05392.pdf
# Descargado: 2403.08717.pdf
# Descargado: 2405.03769.pdf
# Descargado: 2405.05303.pdf
# Descargado: 2410.07792.pdf
